# %%
# !nvidia-smi
# Out:
# Sun Mar 23 11:20:27 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 949.8/949.8 kB 22.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 98.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 82.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 51.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.2.51

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.51 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.2/112.6 GB disk)

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.51 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.2/112.6 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# Mount Google Drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/AhmadY9
# Out:
# /content/drive/MyDrive/AhmadY9

# %%
# !ls
# Out:
# Ahmad_yolo9.ipynb  data  data.yaml

# %%
import torch
print(torch.__version__)
# Out:
# 2.6.0+cu124

# %%
# %cd /content/drive/MyDrive/AhmadY9

# !yolo task=detect mode=train model=yolov9m.pt data=data.yaml epochs=200 imgsz=416 plots=True
# Out:
# /content/drive/MyDrive/AhmadY9
# Ultralytics 8.3.94 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !ls runs/detect/train4
# Out:
# args.yaml					     P_curve.png       train_batch2.jpg
# confusion_matrix_normalized.png			     PR_curve.png      val_batch0_labels.jpg
# confusion_matrix.png				     R_curve.png       val_batch0_pred.jpg
# events.out.tfevents.1742732275.56a96d107915.16610.0  results.csv       val_batch1_labels.jpg
# F1_curve.png					     results.png       val_batch1_pred.jpg
# labels_correlogram.jpg				     train_batch0.jpg  weights
# labels.jpg					     train_batch1.jpg

# %%
Image(filename='runs/detect/train4/train_batch2.jpg', width=1000)

# %%
Image(filename='runs/detect/train4/train_batch0.jpg', width=1000)

# %%
Image(filename='runs/detect/train4/results.png', width=1000)

# %%
Image(filename='runs/detect/train4/confusion_matrix_normalized.png', width=1000)

# %% [markdown]
# # Model Validation

# %%
# !yolo task=detect mode=val model=runs/detect/train4/weights/best.pt data=data.yaml
# Out:
# Ultralytics 8.3.94 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv9s summary (fused): 197 layers, 7,167,862 parameters, 0 gradients, 26.7 GFLOPs
# val: Scanning /content/drive/MyDrive/AhmadY9/data/valid/labels.cache... 38 images, 0 backgrounds, 0 corrupt: 100% 38/38 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 3/3 [00:01<00:00,  2.23it/s]
#                    all         38         39      0.961       0.57        0.7      0.382
#                bicycle         18         18          1      0.427      0.584      0.352
#             motorcycle         20         21      0.922      0.714      0.817      0.412
# Speed: 2.0ms preprocess, 17.7ms inference, 0.0ms loss, 8.1ms postprocess per image
# Results saved to runs/detect/val4
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !ls runs/detect/val4
# Out:
# confusion_matrix_normalized.png  P_curve.png   val_batch0_labels.jpg  val_batch1_pred.jpg
# confusion_matrix.png		 PR_curve.png  val_batch0_pred.jpg    val_batch2_labels.jpg
# F1_curve.png			 R_curve.png   val_batch1_labels.jpg  val_batch2_pred.jpg

# %%
Image(filename='runs/detect/val4/val_batch0_labels.jpg', width=1000)

# %%
Image(filename='runs/detect/val4/confusion_matrix_normalized.png', width=1000)
